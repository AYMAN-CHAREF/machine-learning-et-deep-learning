# %% [markdown]
# <a href="https://colab.research.google.com/github/AYMAN-CHAREF/machine-learning-et-deep-learning/blob/main/Matrice%20et%20Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
A = np.array([[1,2],[3,4],[5,6]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
A.shape
# Out:
# (3, 2)

# %%
B=A.T

# %%
B
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
B.shape
# Out:
# (2, 3)

# %%
A
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
B = np.ones((3,2))
B
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
A + B
# Out:
# array([[2., 3.],
#        [4., 5.],
#        [6., 7.]])

# %%
  A
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
B
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
B.shape
# Out:
# (3, 2)

# %%
A.shape
# Out:
# (3, 2)

# %%
A.dot(B)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-1e3a8194ce1e> in <cell line: 0>()
# ----> 1 A.dot(B)
#
# ValueError: shapes (3,2) and (3,2) not aligned: 2 (dim 1) != 3 (dim 0)

# %%
A.dot(B.T)
# Out:
# array([[ 3.,  3.,  3.],
#        [ 7.,  7.,  7.],
#        [11., 11., 11.]])

# %%
B
# Out:
# array([[1., 1.],
#        [1., 1.],
#        [1., 1.]])

# %%
B.T
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
B.T.shape
# Out:
# (2, 3)

# %%
A.shape
# Out:
# (3, 2)
