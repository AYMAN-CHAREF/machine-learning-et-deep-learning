# %% [markdown]
# <a href="https://colab.research.google.com/github/AYMAN-CHAREF/machine-learning-et-deep-learning/blob/main/KNN_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pour générer des données, nous allons également utiliser la fonction make blobs provenant de
# scikit learn.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Commençons donc par simuler des données. Ici, nous allons créer deux classes y, avec 50 points,
# et deux variables X. Nous allons également générer des points dont la classe est inconnue.

# %%
X, y = make_blobs ( n_samples=50, centers=2, n_features =2, random_state=0, cluster_std =1)

X_new = np.random.uniform(low=X.min(), high=X.max(), size=(10,2))
plt.scatter(X[:,0], X[:,1], c=y, cmap="bwr")

plt.scatter(X_new[:,0], X_new[:,1], c='white', edgecolor='k')
plt.show()

# %% [markdown]
# Pour entraîner le modèle de KNeighborsClassifier, nous allons l’initialiser avec une valeur k=3,
# puis utiliser la méthode fit() comme vu dans le chapitre sur la régression.

# %%
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Enfin, pour effectuer des prédictions et classer les nouveaux points de notre jeu de données,
# on utilise la méthode predict(). On arrive ainsi à classer les nouveaux points du jeu de données.

# %%
predctions = model.predict(X_new)
plt.scatter(X[:,0], X[:,1], c=y, cmap="bwr")
plt.scatter(X_new[:,0], X_new[:,1], c=predctions, cmap="bwr")
plt.show()
