# %% [markdown]
# <a href="https://colab.research.google.com/github/AYMAN-CHAREF/machine-learning-et-deep-learning/blob/main/R%C3%89GRESSION_LIN%C3%89AIRE_NUMPY_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Creation d'un programme de regression lineaire avec Numpy**
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt

# %%
x, y = make_regression(n_samples=100, n_features=1, noise=10)
plt.scatter(x, y)

# %%
print(x.shape)
print(y.shape)
# Out:
# (100, 1)
# (100,)

# %%
#y=y.reshape(100,1)

# %%
#print(x.shape)
#print(y.shape)
# Out:
# (100, 1)
# (100, 1)

# %%
print(x.shape)
y=y.reshape(y.shape[0],1)
print(y.shape)
# Out:
# (100, 1)
# (100, 1)

# %%
#matrice x
X = np.hstack((x,np.ones(x.shape)))
X.shape
# Out:
# (100, 2)

# %%
X
# Out:
# array([[-0.25613422,  1.        ],
#        [ 0.15401925,  1.        ],
#        [-0.49083347,  1.        ],
#        [-0.16045348,  1.        ],
#        [-0.41735434,  1.        ],
#        [-1.43785097,  1.        ],
#        [-0.40729321,  1.        ],
#        [-0.20034912,  1.        ],
#        [ 0.22679228,  1.        ],
#        [-1.29485526,  1.        ],
#        [ 2.27784764,  1.        ],
#        [ 1.58493993,  1.        ],
#        [ 1.49175113,  1.        ],
#        [ 0.70867014,  1.        ],
#        [ 0.48553491,  1.        ],
#        [ 1.09504516,  1.        ],
#        [ 0.49747526,  1.        ],
#        [ 0.31677986,  1.        ],
#        [ 0.91681625,  1.        ],
#        [-0.58529872,  1.        ],
#        [ 1.2614372 ,  1.        ],
#        [-0.38297625,  1.        ],
#        [-0.01688318,  1.        ],
#        [-0.47343541,  1.        ],
#        [ 0.07297929,  1.        ],
#        [ 0.06469373,  1.        ],
#        [-1.99431988,  1.        ],
# ...

# %%
theta = np.random.rand(2,1)
theta.shape
# Out:
# (2, 1)

# %%
theta
# Out:
# array([[0.84066399],
#        [0.13926601]])

# %% [markdown]
# ## Modele Lineaire

# %%
def model(X, theata):
    return X.dot(theta)

# %%
plt.scatter(x,y)
plt.plot(x,model(X, theta), c='r')

# %% [markdown]
# # Fonction cout

# %%
def cost_function (X, y, theta):
  m =len(y)
  return 1/(2*m) * np.sum((model(X,theta)-y)**2)

# %%
cost_function (X, y, theta)
# Out:
# np.float64(1378.5301893264038)
